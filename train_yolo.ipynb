# %%
#確認版本
import cv2
from ultralytics import YOLO
import torch
import torchvision.models as models
import torchvision
import sys 
print(sys.version)

# 检查GPU是否可用
if torch.cuda.is_available():
    device = torch.device("cuda")
    print('Using GPU for training and inference.')
else:
    device = torch.device("cpu")
    print('GPU not detected, using CPU.')

print(torch.__version__)  # 应该输出 2.3.0+cu121
print(torchvision.__version__)  # 应该输出 0.15.2+cu121
print(torch.version.cuda)
# Out:
# 3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]
# Using GPU for training and inference.
# 2.3.1+cu121
# 0.18.1+cu121
# 12.1

# %%
import os
from pathlib import Path
from ultralytics import YOLO

current_dir = os.getcwd()
file_path = os.path.join(current_dir, 'data.yaml')
            
if os.path.exists(file_path):
    print("File exists")
else:
    print("File does not exist")

# YOLOv8 model path
model_path = os.path.join(current_dir, 'yolov8_trained2_0719.pt')
# 訓練模型
model.train(data=file_path, epochs=50, imgsz=640)


try:
    metrics = model.val()
    
    # 打印模型評估结果
    print(metrics)
except RuntimeError as e:
    print(f"Validation failed: {e}")
# Out:
# File exists
# 開始訓練
# New https://pypi.org/project/ultralytics/8.2.59 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.54  Python-3.11.9 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# 儲存訓練後的模型
save_dir = current_dir
Path(save_dir).mkdir(parents=True, exist_ok=True)  # 確保目錄存在
model.save(f'{save_dir}/yolov8_trained.pt')
print(f'Model saved to {save_dir}/yolov8_trained.pt')

# %%
import cv2
from ultralytics import YOLO
# 測試影像路徑

test_img_path = os.path.join(current_dir, '1.jpg')                                                                               
# 加載模型
model_path = os.path.join(current_dir, 'yolov8_trained2_0719.pt')
model1 = YOLO(model_path)
model1.model.names = {0: 'Ball', 1: 'Hoop', 2: 'Player'}


# 讀取測試影像
img = cv2.imread(test_img_path)

# %matplotlib inline
# 或者
# %matplotlib notebook
import matplotlib.pyplot as plt
import cv2

# 執行預測
results = model1.predict(img)

# 可視化结果
annotated_img = results[0].plot()

# 使用 matplotlib 顯示圖片
plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
plt.axis('off')  # 不顯示座標軸
plt.title('Detected Objects')
plt.show()
# Out:
# 0: 288x512 1 Hoop, 8 Players, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 254.0ms postprocess per image at shape (1, 3, 288, 512)
